# %% [markdown]
# # Laptop Price Dataset Analysis & Visualization

# %%
import numpy as np
import pandas as pd
# Out:
# C:\Users\Abubakar\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df=pd.read_csv(r'C:\Users\Abubakar\OneDrive\Desktop\laptop_price_data.csv')
df.sample(5)
# Out:
#       Unnamed: 0 Company  TypeName  Inches                 ScreenResolution  \
# 496          496  Lenovo  Notebook    15.6                Full HD 1920x1080
# 820          820  Lenovo  Notebook    15.6                         1366x768
# 1017        1017  Lenovo  Notebook    17.3  IPS Panel 4K Ultra HD 3840x2160
# 1003        1003      HP  Notebook    14.0                         1366x768
# 687          687    Dell  Notebook    15.6                         1366x768
#
#                               Cpu   Ram     Memory                     Gpu  \
# 496    Intel Core i7 8550U 1.8GHz   8GB  256GB SSD  Intel UHD Graphics 620
# 820      Intel Core i3 6006U 2GHz   4GB  500GB HDD   Intel HD Graphics 520
# 1017  Intel Core i7 6820HQ 2.7GHz  16GB  512GB SSD     Nvidia Quadro 3000M
# 1003   Intel Core i5 7200U 2.5GHz   4GB  500GB HDD   Intel HD Graphics 620
# 687      Intel Core i3 6006U 2GHz   4GB    1TB HDD      AMD Radeon R5 M430
#
#            OpSys  Weight        Price
# ...

# %% [markdown]
# # Step 1: Data Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)
df.sample(5)
# Out:
#      Company   TypeName  Inches                    ScreenResolution  \
# 1069   Apple  Ultrabook    12.0  IPS Panel Retina Display 2304x1440
# 127     Asus   Notebook    14.0                            1366x768
# 720   Lenovo  Ultrabook    14.0        IPS Panel Quad HD+ 2560x1440
# 460     Acer   Notebook    15.6                   Full HD 1920x1080
# 747       HP   Notebook    15.6                   Full HD 1920x1080
#
#                              Cpu  Ram               Memory  \
# 1069         Intel Core M 1.1GHz  8GB  256GB Flash Storage
# 127     AMD E-Series 6110 1.5GHz  4GB             64GB SSD
# 720   Intel Core i7 6500U 2.5GHz  8GB            512GB SSD
# 460     Intel Core i3 6006U 2GHz  4GB              1TB HDD
# 747     Intel Core i3 6006U 2GHz  8GB            256GB SSD
#
#                         Gpu         OpSys   Weight       Price
# 1069  Intel HD Graphics 515      Mac OS X  0.920kg  69264.0000
# 127           AMD Radeon R2  Windows 10 S   1.65kg  14811.3072
# ...

# %%
df['Ram']=df['Ram'].str.replace('GB','')
df['Weight']=df['Weight'].str.replace('kg','')

df.sample(5)
# Out:
#       Company   TypeName  Inches   ScreenResolution  \
# 272      Dell   Notebook    15.6  Full HD 1920x1080
# 1216     Acer   Notebook    17.3           1600x900
# 13       Dell   Notebook    15.6  Full HD 1920x1080
# 7       Apple  Ultrabook    13.3           1440x900
# 746   Samsung  Ultrabook    13.3  Full HD 1920x1080
#
#                              Cpu Ram               Memory  \
# 272   Intel Core i7 8550U 1.8GHz   8            256GB SSD
# 1216    Intel Core i3 6006U 2GHz   4              1TB HDD
# 13      Intel Core i3 6006U 2GHz   4            256GB SSD
# 7           Intel Core i5 1.8GHz   8  256GB Flash Storage
# 746   Intel Core i7 7500U 2.7GHz  16            256GB SSD
#
#                          Gpu       OpSys Weight       Price
# 272           AMD Radeon 520       Linux   2.14  39164.5296
# 1216    Nvidia GeForce 940MX  Windows 10    3.3  31861.4400
# 13        AMD Radeon R5 M430  Windows 10    2.2  26581.3920
# ...

# %%
df['Ram']=df['Ram'].astype('int32')
df['Weight']=df['Weight'].astype('float32')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %% [markdown]
# # Step 2: EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(df['Price'],hist=False)
plt.show()
# Out:
# C:\Users\Abubakar\AppData\Local\Temp\ipykernel_19524\3801764631.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'],hist=False)

# %%
df['Company'].value_counts().plot(kind='bar')
plt.grid()

# %%
sns.barplot(x=df['Company'],y=df['Price'],estimator='mean')
plt.xticks(rotation='vertical')

plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Inches'])
# Out:
# C:\Users\Abubakar\AppData\Local\Temp\ipykernel_19524\1439577752.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'])
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
plt.show()

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
sns.scatterplot(x=df['ScreenResolution'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)
df.sample(5)
# Out:
#       Company   TypeName  Inches                 ScreenResolution  \
# 987    Lenovo     Gaming    15.6      IPS Panel Full HD 1920x1080
# 1239   Lenovo   Notebook    13.3      IPS Panel Full HD 1920x1080
# 491   Toshiba  Ultrabook    13.3  Full HD / Touchscreen 1920x1080
# 202      Acer   Notebook    15.6                Full HD 1920x1080
# 753    Lenovo  Ultrabook    14.0                Full HD 1920x1080
#
#                               Cpu  Ram                Memory  \
# 987   Intel Core i7 7700HQ 2.8GHz    8  128GB SSD +  1TB HDD
# 1239   Intel Core i7 7500U 2.7GHz   16             512GB SSD
# 491    Intel Core i7 7500U 2.7GHz   32             512GB SSD
# 202    Intel Core i7 7500U 2.7GHz    8               1TB HDD
# 753    Intel Core i5 6200U 2.3GHz    4             180GB SSD
#
#                           Gpu       OpSys  Weight      Price  Touchscreen
# 987   Nvidia GeForce GTX 1060  Windows 10    2.50   63349.92            0
# ...

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
df['IPS Panel'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS Panel' in x else 0)
df.sample(5)
# Out:
#      Company   TypeName  Inches             ScreenResolution  \
# 192   Xiaomi  Ultrabook    13.3  IPS Panel Full HD 1920x1080
# 916       HP   Notebook    13.3            Full HD 1920x1080
# 426     Dell   Notebook    15.6            Full HD 1920x1080
# 152   Lenovo   Notebook    15.6                     1366x768
# 1155      HP   Notebook    15.6            Full HD 1920x1080
#
#                                Cpu  Ram                Memory  \
# 192     Intel Core i5 7200U 2.5GHz    8             256GB SSD
# 916     Intel Core i5 7200U 2.5GHz    8             256GB SSD
# 426     Intel Core i7 8550U 1.8GHz    8  256GB SSD +  2TB HDD
# 152     Intel Core i5 7200U 2.5GHz    4             128GB SSD
# 1155  AMD A6-Series A6-9220 2.5GHz    4             256GB SSD
#
#                         Gpu       OpSys  Weight       Price  Touchscreen  \
# 192    Nvidia GeForce MX150       No OS    1.30  53274.6720            0
# 916   Intel HD Graphics 620  Windows 10    1.49  51148.8000            0
# ...

# %%
df['IPS Panel'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='IPS Panel'>

# %%
sns.barplot(x=df['IPS Panel'],y=df['Price'])
# Out:
# <Axes: xlabel='IPS Panel', ylabel='Price'>

# %%
new = df['ScreenResolution'].str.split('x',n=1,expand=True)
new
# Out:
#                                           0     1
# 0             IPS Panel Retina Display 2560  1600
# 1                                      1440   900
# 2                              Full HD 1920  1080
# 3             IPS Panel Retina Display 2880  1800
# 4             IPS Panel Retina Display 2560  1600
# ...                                     ...   ...
# 1298   IPS Panel Full HD / Touchscreen 1920  1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200  1800
# 1300                                   1366   768
# 1301                                   1366   768
# 1302                                   1366   768
#
# [1303 rows x 2 columns]

# %%
df['x_res'] = new[0]
df['y_res'] = new[1]

df.sample(5)
# Out:
#      Company            TypeName  Inches  \
# 157     Asus  2 in 1 Convertible    13.3
# 180     Dell            Notebook    15.6
# 179       HP  2 in 1 Convertible    13.3
# 1283    Asus            Notebook    15.6
# 1143      HP         Workstation    15.6
#
#                                    ScreenResolution  \
# 157                 Full HD / Touchscreen 1920x1080
# 180                               Full HD 1920x1080
# 179   IPS Panel 4K Ultra HD / Touchscreen 3840x2160
# 1283                                       1366x768
# 1143                    IPS Panel Full HD 1920x1080
#
#                               Cpu  Ram                Memory  \
# 157    Intel Core i5 8250U 1.6GHz    8             256GB SSD
# 180    Intel Core i7 8550U 1.8GHz   16  256GB SSD +  2TB HDD
# 179    Intel Core i5 8250U 1.6GHz    8             256GB SSD
# 1283   Intel Core i7 6500U 2.5GHz    4             500GB HDD
# 1143  Intel Core i7 6700HQ 2.6GHz    8             256GB SSD
#
# ...

# %%
df['x_res'] = df['x_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])
df['x_res']
# Out:
# 0       2560
# 1       1440
# 2       1920
# 3       2880
# 4       2560
#         ...
# 1298    1920
# 1299    3200
# 1300    1366
# 1301    1366
# 1302    1366
# Name: x_res, Length: 1303, dtype: object

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS Panel         1303 non-null   int64
#  13  x_res             1303 non-null   object
#  14  y_res             1303 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(2), object(9)
# ...

# %%
df['x_res'] = df['x_res'].astype('int')
df['y_res'] = df['y_res'].astype('int')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS Panel         1303 non-null   int64
#  13  x_res             1303 non-null   int32
#  14  y_res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# ...

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS Panel      0.252208
# x_res          0.556529
# y_res          0.552809
# Name: Price, dtype: float64

# %%
df['PPI'] = (((df['x_res']**2) + (df['y_res']**2))**0.5/df['Inches']).astype('float')
df['PPI']
# Out:
# 0       226.983005
# 1       127.677940
# 2       141.211998
# 3       220.534624
# 4       226.983005
#            ...
# 1298    157.350512
# 1299    276.053530
# 1300    111.935204
# 1301    100.454670
# 1302    100.454670
# Name: PPI, Length: 1303, dtype: float64

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS Panel      0.252208
# x_res          0.556529
# y_res          0.552809
# PPI            0.473487
# Name: Price, dtype: float64

# %%
df.drop(columns=['ScreenResolution','Inches','x_res','y_res'],inplace=True)
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0
#
#    IPS Panel         PPI
# 0          1  226.983005
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df['Cpu Name'] = df['Cpu'].apply(lambda x:' '.join(x.split()[0:3]))
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0
#
#    IPS Panel         PPI       Cpu Name
# ...

# %%
df['Cpu Name'].value_counts()
# Out:
# Cpu Name
# Intel Core i7               527
# Intel Core i5               423
# Intel Core i3               136
# Intel Celeron Dual           80
# Intel Pentium Quad           27
# Intel Core M                 19
# AMD A9-Series 9420           12
# Intel Celeron Quad            8
# AMD A6-Series 9220            8
# AMD A12-Series 9720P          7
# Intel Atom x5-Z8350           5
# AMD A8-Series 7410            4
# Intel Atom x5-Z8550           4
# Intel Pentium Dual            3
# AMD A9-Series 9410            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# AMD A10-Series 9620P          2
# Intel Atom X5-Z8350           2
# AMD E-Series E2-9000e         2
# Intel Xeon E3-1535M           2
# Intel Xeon E3-1505M           2
# AMD E-Series 7110             2
# AMD A10-Series 9600P          2
# AMD A6-Series A6-9220         2
# AMD A10-Series A10-9620P      2
# AMD Ryzen 1600                1
# Intel Atom x5-Z8300           1
# AMD E-Series E2-6110          1
# ...

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0
#
#    IPS Panel         PPI       Cpu Name      Cpu brand
# ...

# %%
df['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu brand'>

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.grid()
plt.show()

# %%
df.drop(columns=['Cpu','Cpu Name'],inplace=True)
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS Panel         PPI  \
# 0  macOS    1.37   71378.6832            0          1  226.983005
# 1  macOS    1.34   47895.5232            0          0  127.677940
# 2  No OS    1.86   30636.0000            0          0  141.211998
# 3  macOS    1.83  135195.3360            0          1  220.534624
# 4  macOS    1.37   96095.8080            0          1  226.983005
#
#        Cpu brand
# 0  Intel Core i5
# 1  Intel Core i5
# 2  Intel Core i5
# 3  Intel Core i7
# ...

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.grid()
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...
